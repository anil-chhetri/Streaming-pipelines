# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("Kafka-Spark-Integration") \
    .master("local") \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://bd4526dd1fc4:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Kafka-Spark-Integration</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "kafka:9092") \
    .option("subscribe", "user-events") \
    .option("startingOffsets", "earliest") \
    .load()

# %%
df.schema
# Out:
# StructType([StructField('key', BinaryType(), True), StructField('value', BinaryType(), True), StructField('topic', StringType(), True), StructField('partition', IntegerType(), True), StructField('offset', LongType(), True), StructField('timestamp', TimestampType(), True), StructField('timestampType', IntegerType(), True)])

# %%
parsed_df = df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# %%
query = parsed_df \
    .writeStream \
    .format("console") \
    .outputMode("append") \
    .start()

# %%
# After starting the query
print(f"Query is active: {query.isActive}")
print(f"Query name: {query.name}")
print(f"Query ID: {query.id}")

# You can also monitor the progress of the query
import time
for _ in range(5):  # Check progress 5 times
    print(query.status)
    time.sleep(2)  # Wait 2 seconds between checks
# Out:
# Query is active: True
# Query name: None
# Query ID: 55e9e7c7-4b8e-4271-9d0e-a1066f846437
# {'message': 'Getting offsets from KafkaV2[Subscribe[user-events]]', 'isDataAvailable': False, 'isTriggerActive': True}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# {'message': 'Waiting for data to arrive', 'isDataAvailable': False, 'isTriggerActive': False}
# {'message': 'Waiting for data to arrive', 'isDataAvailable': False, 'isTriggerActive': False}
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}

# %%
# Get the most recent progress metrics
recent_progress = query.recentProgress
if recent_progress:
    for progress in recent_progress:
        print(f"Input rate: {progress.get('inputRate', 'N/A')} records/sec")
        print(f"Processing rate: {progress.get('processedRowsPerSecond', 'N/A')} rows/sec")
        print(f"Batch duration: {progress.get('batchDuration', 'N/A')} ms")
else:
    print("No progress metrics available yet")
# Out:
# Input rate: N/A records/sec
# Processing rate: 330.75933075933074 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4104372355430184 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3986013986013988 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.297016861219196 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.2658227848101264 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3262599469496021 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.430615164520744 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4104372355430184 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.451378809869376 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4409221902017293 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4347202295552368 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4204545454545456 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3458950201884252 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3888888888888888 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4947683109118086 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.2919896640826873 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5313935681470137 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4388489208633095 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4471780028943562 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4925373134328357 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5037593984962405 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3793103448275863 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3192612137203166 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3966480446927374 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3793103448275863 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3812154696132597 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4598540145985401 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3227513227513228 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4245014245014247 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3245033112582782 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.394700139470014 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4814814814814814 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3477088948787062 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4814814814814814 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3812154696132597 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4534883720930234 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4771048744460855 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5503875968992247 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4925373134328357 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.567398119122257 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.547987616099071 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4124293785310735 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4577259475218658 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.392757660167131 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4492753623188408 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6286644951140066 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.567398119122257 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5220700152207 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5552099533437014 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4285714285714286 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5527950310559007 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5220700152207 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5552099533437014 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6181229773462784 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5220700152207 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6155088852988693 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5873015873015872 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5360983102918586 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5015015015015014 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.4749262536873156 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5552099533437014 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5772870662460567 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.358695652173913 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.519756838905775 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.524390243902439 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5174506828528072 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.392757660167131 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5552099533437014 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5822784810126582 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5220700152207 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6025641025641026 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.3850415512465375 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.5384615384615383 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.567398119122257 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.607717041800643 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6025641025641026 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6051364365971108 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6207455429497568 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.6181229773462784 rows/sec
# Batch duration: N/A ms
# Input rate: N/A records/sec
# Processing rate: 1.519756838905775 rows/sec
# Batch duration: N/A ms

# %%
# Start the streaming query writing to an in-memory table
query = parsed_df \
    .writeStream \
    .format("memory") \
    .queryName("kafka_data") \
    .outputMode("append") \
    .start()

# Give it a moment to process some data
time.sleep(5)

# Now you can query the in-memory table
spark.sql("SELECT * FROM kafka_data").show()
# Out:
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# |NULL|{"event_time": "2...|
# +----+--------------------+
# only showing top 20 rows

# %%
spark.sql("SELECT * FROM kafka_data").show(truncate=False)
# Out:
# +----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |key |value                                                                                                                                                                                |
# +----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |NULL|{"event_time": "2025-03-20T00:04:11.782493", "event_type": "remove_from_cart", "user_id": "user_12", "product_id": "product_471", "category": "toys", "price": 64.86, "quantity": 1} |
# |NULL|{"event_time": "2025-03-20T00:04:40.109885", "event_type": "purchase", "user_id": "user_44", "product_id": "product_115", "category": "home", "price": 474.35, "quantity": 1}        |
# |NULL|{"event_time": "2025-03-20T00:04:15.111787", "event_type": "cart", "user_id": "user_97", "product_id": "product_227", "category": "clothing", "price": 342.13, "quantity": 1}        |
# |NULL|{"event_time": "2025-03-20T00:04:32.115214", "event_type": "view", "user_id": "user_14", "product_id": "product_480", "category": "toys", "price": 352.19, "quantity": 4}            |
# |NULL|{"event_time": "2025-03-20T00:04:16.118543", "event_type": "view", "user_id": "user_63", "product_id": "product_436", "category": "sports", "price": 313.92, "quantity": 3}          |
# |NULL|{"event_time": "2025-03-20T00:04:40.120070", "event_type": "wishlist", "user_id": "user_61", "product_id": "product_63", "category": "sports", "price": 231.99, "quantity": 2}       |
# |NULL|{"event_time": "2025-03-20T00:04:01.121995", "event_type": "remove_from_cart", "user_id": "user_2", "product_id": "product_253", "category": "toys", "price": 165.9, "quantity": 5}  |
# |NULL|{"event_time": "2025-03-20T00:04:12.125275", "event_type": "purchase", "user_id": "user_17", "product_id": "product_478", "category": "clothing", "price": 323.64, "quantity": 3}    |
# |NULL|{"event_time": "2025-03-20T00:04:08.126121", "event_type": "wishlist", "user_id": "user_68", "product_id": "product_339", "category": "sports", "price": 42.83, "quantity": 1}       |
# |NULL|{"event_time": "2025-03-20T00:04:32.127659", "event_type": "purchase", "user_id": "user_9", "product_id": "product_418", "category": "home", "price": 305.55, "quantity": 2}         |
# |NULL|{"event_time": "2025-03-20T00:04:21.130986", "event_type": "purchase", "user_id": "user_9", "product_id": "product_86", "category": "home", "price": 346.66, "quantity": 4}          |
# |NULL|{"event_time": "2025-03-20T00:05:08.134241", "event_type": "view", "user_id": "user_99", "product_id": "product_380", "category": "electronics", "price": 102.02, "quantity": 5}     |
# |NULL|{"event_time": "2025-03-20T00:04:51.135245", "event_type": "wishlist", "user_id": "user_47", "product_id": "product_258", "category": "home", "price": 172.88, "quantity": 3}        |
# |NULL|{"event_time": "2025-03-20T00:05:14.138452", "event_type": "cart", "user_id": "user_45", "product_id": "product_334", "category": "toys", "price": 466.19, "quantity": 3}            |
# |NULL|{"event_time": "2025-03-20T00:04:29.140349", "event_type": "wishlist", "user_id": "user_57", "product_id": "product_474", "category": "books", "price": 237.17, "quantity": 1}       |
# |NULL|{"event_time": "2025-03-20T00:04:32.143467", "event_type": "cart", "user_id": "user_58", "product_id": "product_408", "category": "home", "price": 113.52, "quantity": 5}            |
# |NULL|{"event_time": "2025-03-20T00:05:04.146783", "event_type": "purchase", "user_id": "user_81", "product_id": "product_312", "category": "sports", "price": 143.91, "quantity": 5}      |
# |NULL|{"event_time": "2025-03-20T00:04:49.150107", "event_type": "cart", "user_id": "user_75", "product_id": "product_469", "category": "home", "price": 268.61, "quantity": 3}            |
# |NULL|{"event_time": "2025-03-20T00:05:00.152433", "event_type": "wishlist", "user_id": "user_2", "product_id": "product_300", "category": "books", "price": 362.73, "quantity": 3}        |
# |NULL|{"event_time": "2025-03-20T00:05:16.155730", "event_type": "remove_from_cart", "user_id": "user_8", "product_id": "product_45", "category": "sports", "price": 241.31, "quantity": 3}|
# +----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
